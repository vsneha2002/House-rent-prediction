# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('housetrain.csv')
df1=pd.read_csv('test.csv')
df2=pd.read_csv('submission.csv')

# %%
df.head()
# Out:
#    Property_ID  room layout_type      property_type                 locality  \
# 0        42208     3         BHK  Independent House               Palavakkam
# 1        90879     1         BHK          Apartment                Manikonda
# 2        99943     3         BHK          Apartment             Jodhpur Park
# 3       113926     1         BHK          Apartment                  Chembur
# 4       185438     1         BHK   Studio Apartment  Kalewadi Pandhapur Road
#
#    price  area    furnish_type  bathroom       city  ...  floor  pet_friendly  \
# 0  33624  1312       Furnished         2    Chennai  ...      1             1
# 1   9655  1474     Unfurnished         2  Hyderabad  ...     17             0
# 2  23699  1837  Semi-Furnished         2    Kolkata  ...     10             1
# 3   6306   606     Unfurnished         1     Mumbai  ...     18             0
# 4  12008   498  Semi-Furnished         3       Pune  ...     14             0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134683 entries, 0 to 134682
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Property_ID       134683 non-null  int64
#  1   room              134683 non-null  int64
#  2   layout_type       134683 non-null  object
#  3   property_type     134683 non-null  object
#  4   locality          134683 non-null  object
#  5   price             134683 non-null  int64
#  6   area              134683 non-null  int64
#  7   furnish_type      134683 non-null  object
#  8   bathroom          134683 non-null  int64
#  9   city              134683 non-null  object
#  10  parking_spaces    134683 non-null  int64
#  11  floor             134683 non-null  int64
#  12  pet_friendly      134683 non-null  int64
#  13  power_backup      134683 non-null  int64
#  14  washing_machine   134683 non-null  int64
#  15  air_conditioner   134683 non-null  int64
# ...

# %%
df.isnull().any()
# Out:
# Property_ID         False
# room                False
# layout_type         False
# property_type       False
# locality            False
# price               False
# area                False
# furnish_type        False
# bathroom            False
# city                False
# parking_spaces      False
# floor               False
# pet_friendly        False
# power_backup        False
# washing_machine     False
# air_conditioner     False
# geyser/solar        False
# security_deposit    False
# CCTV/security       False
# lift                False
# neighbourhood       False
# dtype: bool

# %%
df.drop(columns=['Property_ID'],inplace=True)

df1.drop(columns=['Property_ID'],inplace=True)

df.drop(columns=['pet_friendly'],inplace=True)

df1.drop(columns=['pet_friendly'],inplace=True)

# %%
df.drop(columns=['locality'],inplace=True)

df1.drop(columns=['locality'],inplace=True)

df.drop(columns=['geyser/solar'],inplace=True)

df1.drop(columns=['geyser/solar'],inplace=True)
df.drop(columns=['lift'],inplace=True)

df1.drop(columns=['lift'],inplace=True)

df.drop(columns=['CCTV/security'],inplace=True)
df1.drop(columns=['CCTV/security'],inplace=True)



df.drop(columns=['washing_machine'],inplace=True)
df1.drop(columns=['washing_machine'],inplace=True)

df.drop(columns=['air_conditioner'],inplace=True)
df1.drop(columns=['air_conditioner'],inplace=True)

# %%
df[['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','security_deposit','neighbourhood','price']]
# Out:
#         room layout_type      property_type  area    furnish_type  bathroom  \
# 0          3         BHK  Independent House  1312       Furnished         2
# 1          1         BHK          Apartment  1474     Unfurnished         2
# 2          3         BHK          Apartment  1837  Semi-Furnished         2
# 3          1         BHK          Apartment   606     Unfurnished         1
# 4          1         BHK   Studio Apartment   498  Semi-Furnished         3
# ...      ...         ...                ...   ...             ...       ...
# 134678     3         BHK  Independent Floor   641     Unfurnished         1
# 134679     1         BHK  Independent Floor   619     Unfurnished         2
# 134680     3         BHK          Apartment  2279  Semi-Furnished         3
# 134681     1         BHK          Apartment  1314     Unfurnished         2
# 134682     1          RK  Independent Floor   798  Semi-Furnished         2
#
# ...

# %%
df1[['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','security_deposit','neighbourhood','price']]
# Out:
#        room layout_type      property_type  area    furnish_type  bathroom  \
# 0         2         BHK  Independent Floor  1347  Semi-Furnished         1
# 1         1         BHK  Independent House   634  Semi-Furnished         3
# 2         1         BHK          Apartment   524     Unfurnished         1
# 3         3         BHK          Apartment  1837     Unfurnished         5
# 4         2         BHK          Apartment  1208  Semi-Furnished         2
# ...     ...         ...                ...   ...             ...       ...
# 57717     3         BHK          Apartment  1628  Semi-Furnished         2
# 57718     1         BHK          Apartment   729     Unfurnished         1
# 57719     3          RK  Independent Floor   897       Furnished         3
# 57720     3         BHK  Independent Floor  2229     Unfurnished         1
# 57721     2         BHK          Apartment   839  Semi-Furnished         3
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.layout_type=le.fit_transform(df.layout_type)
df.city=le.fit_transform(df.city)
df.furnish_type=le.fit_transform(df.furnish_type)
df.property_type=le.fit_transform(df.property_type)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1.layout_type=le.fit_transform(df1.layout_type)
df1.city=le.fit_transform(df1.city)
df1.furnish_type=le.fit_transform(df1.furnish_type)
df1.property_type=le.fit_transform(df1.property_type)

# %%
df
# Out:
#         room  layout_type  property_type   price  area  furnish_type  \
# 0          3            0              2   33624  1312             0
# 1          1            0              0    9655  1474             2
# 2          3            0              0   23699  1837             1
# 3          1            0              0    6306   606             2
# 4          1            0              4   12008   498             1
# ...      ...          ...            ...     ...   ...           ...
# 134678     3            0              1  222987   641             2
# 134679     1            0              1    6958   619             2
# 134680     3            0              0   85812  2279             1
# 134681     1            0              0   15919  1314             2
# 134682     1            1              1   37021   798             1
#
#         bathroom  city  parking_spaces  floor  power_backup  security_deposit  \
# ...

# %%
X=df.drop(['price'], axis = 1)
y=df['price']

# %%
df1["price"]=0

# %%
test_x=df1.iloc[:,:-1].values
test_y = df1["price"]

# %%
y
# Out:
# 0          33624
# 1           9655
# 2          23699
# 3           6306
# 4          12008
#            ...
# 134678    222987
# 134679      6958
# 134680     85812
# 134681     15919
# 134682     37021
# Name: price, Length: 134683, dtype: int64

# %%
from sklearn.preprocessing import RobustScaler


scale=RobustScaler()

scale.fit(X)
# Out:
# RobustScaler()

# %%
X= scale.transform(X)

# %%
scale.fit(test_x)
# Out:
# RobustScaler()

# %%
X_test= scale.transform(test_x)

# %%
from sklearn import linear_model

reg1=linear_model.LinearRegression()
reg1.fit(df[['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','security_deposit','neighbourhood']],df.price)

y_pred = reg1.predict(test_x)

y_pred



from sklearn.metrics import mean_squared_error

mse1 = mean_squared_error(test_y, y_pred)

import math

rmse1 = math.sqrt(mse1)

print(rmse1)
# Out:
# 67180.92533975515

# %%
df2 = pd.DataFrame({
    "submission": y_pred
})

df2.to_csv("submission1.csv", index=False)

# %%
df2
# Out:
#          submission
# 0      16237.232482
# 1       9790.617186
# 2       7390.210295
# 3      27193.930110
# 4      23468.628143
# ...             ...
# 57717  17893.706702
# 57718   9183.423983
# 57719  34503.527528
# 57720  20874.478770
# 57721  18919.040229
#
# [57722 rows x 1 columns]
