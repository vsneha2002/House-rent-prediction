# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('housetrain.csv')
df1=pd.read_csv('test.csv')
df2=pd.read_csv('submission.csv')

# %%
df.head()
# Out:
#    Property_ID  room layout_type      property_type                 locality  \
# 0        42208     3         BHK  Independent House               Palavakkam
# 1        90879     1         BHK          Apartment                Manikonda
# 2        99943     3         BHK          Apartment             Jodhpur Park
# 3       113926     1         BHK          Apartment                  Chembur
# 4       185438     1         BHK   Studio Apartment  Kalewadi Pandhapur Road
#
#    price  area    furnish_type  bathroom       city  ...  floor  pet_friendly  \
# 0  33624  1312       Furnished         2    Chennai  ...      1             1
# 1   9655  1474     Unfurnished         2  Hyderabad  ...     17             0
# 2  23699  1837  Semi-Furnished         2    Kolkata  ...     10             1
# 3   6306   606     Unfurnished         1     Mumbai  ...     18             0
# 4  12008   498  Semi-Furnished         3       Pune  ...     14             0
#
# ...

# %%
df1.head()
# Out:
#    Property_ID  room layout_type      property_type         locality  area  \
# 0       114342     2         BHK  Independent Floor           Palava  1347
# 1        88819     1         BHK  Independent House       Somajiguda   634
# 2        85623     1         BHK          Apartment      Toli Chowki   524
# 3       130856     3         BHK          Apartment       Thane West  1837
# 4        40089     2         BHK          Apartment  Krishnarajapura  1208
#
#      furnish_type  bathroom       city  parking_spaces  ...  pet_friendly  \
# 0  Semi-Furnished         1     Mumbai               0  ...             0
# 1  Semi-Furnished         3  Hyderabad               1  ...             0
# 2     Unfurnished         1  Hyderabad               1  ...             1
# 3     Unfurnished         5     Mumbai               1  ...             1
# 4  Semi-Furnished         2  Bangalore               1  ...             0
#
#    power_backup  washing_machine  air_conditioner  geyser/solar  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134683 entries, 0 to 134682
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Property_ID       134683 non-null  int64
#  1   room              134683 non-null  int64
#  2   layout_type       134683 non-null  object
#  3   property_type     134683 non-null  object
#  4   locality          134683 non-null  object
#  5   price             134683 non-null  int64
#  6   area              134683 non-null  int64
#  7   furnish_type      134683 non-null  object
#  8   bathroom          134683 non-null  int64
#  9   city              134683 non-null  object
#  10  parking_spaces    134683 non-null  int64
#  11  floor             134683 non-null  int64
#  12  pet_friendly      134683 non-null  int64
#  13  power_backup      134683 non-null  int64
#  14  washing_machine   134683 non-null  int64
#  15  air_conditioner   134683 non-null  int64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57722 entries, 0 to 57721
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Property_ID       57722 non-null  int64
#  1   room              57722 non-null  int64
#  2   layout_type       57722 non-null  object
#  3   property_type     57722 non-null  object
#  4   locality          57722 non-null  object
#  5   area              57722 non-null  int64
#  6   furnish_type      57722 non-null  object
#  7   bathroom          57722 non-null  int64
#  8   city              57722 non-null  object
#  9   parking_spaces    57722 non-null  int64
#  10  floor             57722 non-null  int64
#  11  pet_friendly      57722 non-null  int64
#  12  power_backup      57722 non-null  int64
#  13  washing_machine   57722 non-null  int64
#  14  air_conditioner   57722 non-null  int64
#  15  geyser/solar      57722 non-null  int64
# ...

# %%
df.isnull().any()
# Out:
# Property_ID         False
# room                False
# layout_type         False
# property_type       False
# locality            False
# price               False
# area                False
# furnish_type        False
# bathroom            False
# city                False
# parking_spaces      False
# floor               False
# pet_friendly        False
# power_backup        False
# washing_machine     False
# air_conditioner     False
# geyser/solar        False
# security_deposit    False
# CCTV/security       False
# lift                False
# neighbourhood       False
# dtype: bool

# %%
df1.isnull().any()
# Out:
# Property_ID         False
# room                False
# layout_type         False
# property_type       False
# locality            False
# area                False
# furnish_type        False
# bathroom            False
# city                False
# parking_spaces      False
# floor               False
# pet_friendly        False
# power_backup        False
# washing_machine     False
# air_conditioner     False
# geyser/solar        False
# security_deposit    False
# CCTV/security       False
# lift                False
# neighbourhood       False
# price                True
# dtype: bool

# %%
df.drop(columns=['Property_ID'],inplace=True)

# %%
df1.drop(columns=['Property_ID'],inplace=True)

# %%
df.drop(columns=['pet_friendly'],inplace=True)

# %%
df1.drop(columns=['pet_friendly'],inplace=True)

# %%
df.head()
# Out:
#    room layout_type      property_type                 locality  price  area  \
# 0     3         BHK  Independent House               Palavakkam  33624  1312
# 1     1         BHK          Apartment                Manikonda   9655  1474
# 2     3         BHK          Apartment             Jodhpur Park  23699  1837
# 3     1         BHK          Apartment                  Chembur   6306   606
# 4     1         BHK   Studio Apartment  Kalewadi Pandhapur Road  12008   498
#
#      furnish_type  bathroom       city  parking_spaces  floor  power_backup  \
# 0       Furnished         2    Chennai               1      1             0
# 1     Unfurnished         2  Hyderabad               0     17             1
# 2  Semi-Furnished         2    Kolkata               0     10             1
# 3     Unfurnished         1     Mumbai               0     18             0
# 4  Semi-Furnished         3       Pune               0     14             0
#
# ...

# %%
df['property_type'].unique()
# Out:
# array(['Independent House', 'Apartment', 'Studio Apartment',
#        'Independent Floor', 'Villa', 'Penthouse'], dtype=object)

# %%
df['furnish_type'].unique()
# Out:
# array(['Furnished', 'Unfurnished', 'Semi-Furnished'], dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Chennai', 'Hyderabad', 'Kolkata', 'Mumbai', 'Pune', 'Delhi',
#        'Bangalore', 'Ahmedabad'], dtype=object)

# %%
df['layout_type'].unique()
# Out:
# array(['BHK', 'RK'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.layout_type=le.fit_transform(df.layout_type)
df.city=le.fit_transform(df.city)
df.furnish_type=le.fit_transform(df.furnish_type)
df.property_type=le.fit_transform(df.property_type)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1.layout_type=le.fit_transform(df1.layout_type)
df1.city=le.fit_transform(df1.city)
df1.furnish_type=le.fit_transform(df1.furnish_type)
df1.property_type=le.fit_transform(df1.property_type)

# %%
df.head()
# Out:
#    room  layout_type  property_type                 locality  price  area  \
# 0     3            0              2               Palavakkam  33624  1312
# 1     1            0              0                Manikonda   9655  1474
# 2     3            0              0             Jodhpur Park  23699  1837
# 3     1            0              0                  Chembur   6306   606
# 4     1            0              4  Kalewadi Pandhapur Road  12008   498
#
#    furnish_type  bathroom  city  parking_spaces  floor  power_backup  \
# 0             0         2     2               1      1             0
# 1             2         2     4               0     17             1
# 2             1         2     5               0     10             1
# 3             2         1     6               0     18             0
# 4             1         3     7               0     14             0
#
#    washing_machine  air_conditioner  geyser/solar  security_deposit  \
# ...

# %%
df.drop(columns=['locality'],inplace=True)

# %%
df1.drop(columns=['locality'],inplace=True)

# %%
df.head()
# Out:
#    room  layout_type  property_type  price  area  furnish_type  bathroom  \
# 0     3            0              2  33624  1312             0         2
# 1     1            0              0   9655  1474             2         2
# 2     3            0              0  23699  1837             1         2
# 3     1            0              0   6306   606             2         1
# 4     1            0              4  12008   498             1         3
#
#    city  parking_spaces  floor  power_backup  washing_machine  \
# 0     2               1      1             0                0
# 1     4               0     17             1                0
# 2     5               0     10             1                1
# 3     6               0     18             0                0
# 4     7               0     14             0                1
#
#    air_conditioner  geyser/solar  security_deposit  CCTV/security  lift  \
# 0                1             0            302616              0     0
# ...

# %%
df[['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','washing_machine','air_conditioner','geyser/solar','security_deposit','CCTV/security','lift','neighbourhood','price']]
# Out:
#         room  layout_type  property_type  area  furnish_type  bathroom  city  \
# 0          3            0              2  1312             0         2     2
# 1          1            0              0  1474             2         2     4
# 2          3            0              0  1837             1         2     5
# 3          1            0              0   606             2         1     6
# 4          1            0              4   498             1         3     7
# ...      ...          ...            ...   ...           ...       ...   ...
# 134678     3            0              1   641             2         1     6
# 134679     1            0              1   619             2         2     7
# 134680     3            0              0  2279             1         3     6
# 134681     1            0              0  1314             2         2     7
# 134682     1            1              1   798             1         2     2
#
# ...

# %%
df1
[['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','washing_machine','air_conditioner','geyser/solar','security_deposit','CCTV/security','lift','neighbourhood','price']]
# Out:
# [['room',
#   'layout_type',
#   'property_type',
#   'area',
#   'furnish_type',
#   'bathroom',
#   'city',
#   'parking_spaces',
#   'floor',
#   'power_backup',
#   'washing_machine',
#   'air_conditioner',
#   'geyser/solar',
#   'security_deposit',
#   'CCTV/security',
#   'lift',
#   'neighbourhood',
#   'price']]

# %%
X=df.iloc[:,:-1].values

# %%
y=df.iloc[:,-1]

# %%
X
# Out:
# array([[     3,      0,      2, ..., 302616,      0,      0],
#        [     1,      0,      0, ...,  19310,      0,      1],
#        [     3,      0,      0, ..., 118495,      0,      1],
#        ...,
#        [     3,      0,      0, ..., 429060,      0,      0],
#        [     1,      0,      0, ...,  79595,      0,      1],
#        [     1,      1,      1, ...,  74042,      0,      1]], dtype=int64)

# %%
y
# Out:
# 0          300
# 1         1600
# 2         3100
# 3          300
# 4            0
#           ...
# 134678    3900
# 134679    1200
# 134680    3900
# 134681    2300
# 134682    3600
# Name: neighbourhood, Length: 134683, dtype: int64

# %%
df1["price"]=0

# %%
test_x=df1.iloc[:,:-1].values
test_y = df1["price"]

# %%
test_y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 57717    0
# 57718    0
# 57719    0
# 57720    0
# 57721    0
# Name: price, Length: 57722, dtype: int64

# %%
from sklearn import linear_model

# %%
df2
# Out:
#          submission
# 0      15873.655247
# 1       9891.898417
# 2       7421.667433
# 3      27254.909731
# 4      23539.649026
# ...             ...
# 57717  17975.711450
# 57718   8758.567615
# 57719  34554.065266
# 57720  20921.013322
# 57721  19081.014589
#
# [57722 rows x 1 columns]

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# room                     2.0
# layout_type              0.0
# property_type            1.0
# price                23978.5
# area                   821.0
# furnish_type             1.0
# bathroom                 1.0
# city                     4.0
# parking_spaces           1.0
# floor                   11.0
# power_backup             1.0
# washing_machine          1.0
# air_conditioner          1.0
# geyser/solar             1.0
# security_deposit    164902.0
# CCTV/security            1.0
# lift                     1.0
# neighbourhood         1900.0
# dtype: float64

# %%
print(df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
# Out:
#          room  layout_type  property_type  price   area  furnish_type  \
# 0       False        False          False  False  False         False
# 1       False        False          False  False  False         False
# 2       False        False          False  False  False         False
# 3       False        False          False  False  False         False
# 4       False        False          False  False  False         False
# ...       ...          ...            ...    ...    ...           ...
# 134678  False        False          False  False  False         False
# 134679  False        False          False  False  False         False
# 134680  False        False          False  False  False         False
# 134681  False        False          False  False  False         False
# 134682  False        False          False  False  False         False
#
#         bathroom   city  parking_spaces  floor  power_backup  washing_machine  \
# ...

# %%
print(df['price'])
# Out:
# 0          33624
# 1           9655
# 2          23699
# 3           6306
# 4          12008
#            ...
# 134678    222987
# 134679      6958
# 134680     85812
# 134681     15919
# 134682     37021
# Name: price, Length: 134683, dtype: int64

# %%
ll=['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','washing_machine','air_conditioner','geyser/solar','security_deposit','CCTV/security','lift','neighbourhood']

# %%
len(ll)
# Out:
# 17

# %%
for i in df:
    temp1=df[i].quantile(0.25)
    temp2=df[i].quantile(0.75)
    df[i] = np.where(df[i] <temp1,temp1,df[i])
    df[i] = np.where(df[i] >temp2, temp2,df[i])

# %%
df
# Out:
#         room  layout_type  property_type    price    area  furnish_type  \
# 0        3.0          0.0            1.0  33624.0  1312.0           1.0
# 1        1.0          0.0            0.0  12035.5  1474.0           2.0
# 2        3.0          0.0            0.0  23699.0  1580.0           1.0
# 3        1.0          0.0            0.0  12035.5   759.0           2.0
# 4        1.0          0.0            1.0  12035.5   759.0           1.0
# ...      ...          ...            ...      ...     ...           ...
# 134678   3.0          0.0            1.0  36014.0   759.0           2.0
# 134679   1.0          0.0            1.0  12035.5   759.0           2.0
# 134680   3.0          0.0            0.0  36014.0  1580.0           1.0
# 134681   1.0          0.0            0.0  15919.0  1314.0           2.0
# 134682   1.0          0.0            1.0  36014.0   798.0           1.0
#
#         bathroom  city  parking_spaces  floor  power_backup  washing_machine  \
# ...

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['room','layout_type','property_type','area','furnish_type','bathroom','city','parking_spaces','floor','power_backup','washing_machine','air_conditioner','geyser/solar','security_deposit','CCTV/security','lift','neighbourhood']],df.price)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(test_x)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(test_y, y_pred)

import math

rmse = math.sqrt(mse)

# %%
print(rmse)
# Out:
# 58127.78263420873

# %%
df2 = pd.DataFrame({
    "submission": y_pred
})

df2.to_csv("submission1.csv", index=False)

# %%
df2
# Out:
#          submission
# 0      15980.290514
# 1      11118.437610
# 2       7290.227311
# 3      27221.580681
# 4      21666.934370
# ...             ...
# 57717  17957.465751
# 57718   9757.025639
# 57719  31648.089803
# 57720  20265.095648
# 57721  19217.353670
#
# [57722 rows x 1 columns]
